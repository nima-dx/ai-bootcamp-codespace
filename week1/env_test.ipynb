# %%
from openai import OpenAI

# %%
openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-5.2",
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# In a quiet valley where the grass glittered with morning dew even at night, there lived a small unicorn named Luma. Luma wasn’t the biggest unicorn, and her horn didn’t shine like a lighthouse the way some did. Hers glowed softly—like a candle behind a curtain.
#
# Every evening, when the sky turned the color of blueberries and the first stars blinked awake, the woodland animals would begin to worry.
#
# Because the dark could feel very big.
#
# The rabbits would tuck their paws under their chins. The deer would listen for strange rustles. The owls—who were supposed to be brave—sometimes blinked a little too slowly and wished the shadows were less shadowy.
#
# That’s when Luma would trot to the middle of the clearing and lower her head, as if she were listening to the ground.
#
# “Are you there?” she would whisper.
#
# And the earth would answer in its own gentle way: with the faintest hum, like a song you almost remember.
#
# Luma’s horn would glow a little brighter.
#
# Not bright enough to chase the night away—because night needed to be there, too—but bright enough to make room for calm.
#
# One night, a wind came through the valley, swift and chilly. It shook the trees until they sighed and shivered. The animals huddled close, and even Luma’s glow wavered.
#
# “I don’t like this wind,” murmured a mouse, pressing against a warm stone.
#
# “I think it’s trying to steal the quiet,” said a fox.
#
# Luma took a slow breath in and an even slower breath out. Then she stepped toward the darkest edge of the clearing, where the wind curled like a mischievous ribbon.
#
# “Hello, Wind,” Luma said politely. “You sound busy.”
#
# The wind whooshed and tugged at her mane as if to say, *Yes! I am!*
#
# Luma nodded. “Would you like a job that helps instead of startles?”
#
# The wind paused—just for a moment—surprised to be spoken to so kindly.
#
# Luma leaned closer. “Can you carry the sleepy smells of pine and honey to everyone’s nests? Can you ruffle the leaves into a softer blanket? Can you hush your voice when the little ones are dreaming?”
#
# The wind swirled around her horn. It felt the gentle light there, warm as a lullaby. And slowly—very slowly—it began to change.
#
# It still moved through the trees, but now it moved like a careful hand smoothing a quilt. It still whistled, but softer, like someone humming in the next room. It carried the scent of pine needles and wildflowers, and the valley breathed easier.
#
# The animals blinked and loosened their shoulders.
#
# The rabbits yawned.
#
# The deer lowered their heads.
#
# The owls tucked their wings close and decided that being brave could also mean being sleepy.
#
# Luma returned to the middle of the clearing and curled her legs beneath her. Her horn glowed its candle-glow, steady and patient.
#
# One by one, the animals said goodnight.
#
# “Goodnight, Luma,” whispered the mouse.
#
# “Goodnight,” Luma whispered back.
#
# “Goodnight, Wind,” called the fox.
#
# The wind answered with a quiet *shhhh*—not a warning, but a promise.
#
# Above them, the stars looked especially pleased, as if they’d been waiting for everything to settle into its proper place.
#
# And as the whole valley drifted toward dreams, Luma closed her eyes and listened to the earth’s gentle hum—safe, steady, and soft.
#
# In the end, the night wasn’t big anymore.
#
# It was just wide enough to hold everyone’s sleep.
#
# And Luma’s little light kept glowing, like a bedtime story that didn’t need to be loud to be heard.
